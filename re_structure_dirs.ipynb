# %%
import os
import shutil
from tqdm import tqdm 
import geopandas as gpd

# %%
in_dir = "/mnt/sdd/ls789gf"

for file in tqdm(os.listdir(in_dir)):
    full_path = os.path.join(in_dir, file)
    print(os.path.exists(full_path))
    if not file.endswith("Landsat"):
        os.rename(full_path, os.path.join(in_dir, f"coords_{file}_Landsat"))
# Out:
# 100%|██████████| 2839/2839 [00:00<00:00, 104285.48it/s]
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
in_shp = '/home/rene1337/Desktop/Senegal_2002-2016_merged_cutlines_run10.gpkg'
gdf = gpd.read_file(in_shp)

# %%
gdf.columns
# Out:
# Index(['IMAGENAME', 'SENSOR', 'ACQDATE', 'CAT_ID', 'RESOLUTION', 'OFF_NADIR',
#        'SUN_ELEV', 'SUN_AZ', 'SAT_ELEV', 'SAT_AZ', 'CLOUDCOVER', 'TDI',
#        'DATE_DIFF', 'SCORE', 'SCAN_DIR', 'RF_MULT', 'RF_ADD', 'AOD',
#        'CLOUD_FRAC', 'STATS_MIN', 'STATS_MAX', 'STATS_STD', 'STATS_MEAN',
#        'STATS_PCT', 'geometry'],
#       dtype='object')

# %%
import pandas as pd
gdf["acq_date"] = pd.to_datetime(gdf["ACQDATE"])
gdf["year"] = gdf["acq_date"].dt.year
gdf.to_file('/home/rene1337/Desktop/Senegal_2002-2016_merged_cutlines_run10_with_years.gpkg', driver='GPKG')

# %%
# replace id with unique_id where it exists
gdf["id"] = gdf["unique_id"].where(gdf["unique_id"].notnull(), gdf["id"])

# %%
gdf.to_file(in_shp.replace(".gpkg", "_with_unique_ids.gpkg"), driver="GPKG")

# %%
gdf_unique_ids["id"] = gdf_unique_ids["unique_id"]
# Out:
# /home/rene1337/miniconda3/envs/gdal/lib/python3.10/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
gdf_unique_ids
# Out:
#      fid              id  DeciduousLC  Dormancy_1_mean  MidGreendown_1_mean  \
# 13    53  -19_14_4_part0          NaN              NaN                  NaN
# 14    54  -19_14_4_part1          NaN              NaN                  NaN
# 15    57  -19_14_7_part0          NaN              NaN                  NaN
# 16    58  -19_14_7_part1          NaN              NaN                  NaN
# 17    59  -19_14_7_part2          NaN              NaN                  NaN
# ..   ...             ...          ...              ...                  ...
# 534  452  -16_18_3_part3          NaN              NaN                  NaN
# 535  453  -16_18_1_part0          NaN              NaN                  NaN
# 536  455  -16_18_1_part2          NaN              NaN                  NaN
# 537  456  -16_18_1_part3          NaN              NaN                  NaN
# 538  459  -16_18_2_part2          NaN              NaN                  NaN
#
# ...

# %%
# merge rows where unique_id is the same
joined = gdf.join(gdf_unique_ids, on="fid", rsuffix="_right")

# %%
joined
# Out:
#       fid        id  DeciduousLC  Dormancy_1_mean  MidGreendown_1_mean  \
# 0    3154  -19_15_1    44.974813       361.918330           321.478702
# 1    3157  -19_15_2    44.974813       361.918330           321.478702
# 2    3160  -18_15_0     3.976811       352.541547           316.534154
# 3    3163  -18_15_1     3.976811       352.541547           316.534154
# 4    3166  -18_15_2     3.976811       352.541547           316.534154
# ..    ...       ...          ...              ...                  ...
# 534   452  -16_18_3          NaN              NaN                  NaN
# 535   453  -16_18_1          NaN              NaN                  NaN
# 536   455  -16_18_1          NaN              NaN                  NaN
# 537   456  -16_18_1          NaN              NaN                  NaN
# 538   459  -16_18_2          NaN              NaN                  NaN
#
#      Senescence_1_mean  Greenup_1_mean       unique_id start_date   end_date  \
# ...
